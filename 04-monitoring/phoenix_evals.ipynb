# %%
import phoenix as px
import pandas as pd
import nest_asyncio

from phoenix.client import Client
from phoenix.session.evaluation import get_retrieved_documents, get_qa_with_reference
from phoenix.evals import HallucinationEvaluator, QAEvaluator, RelevanceEvaluator, OpenAIModel, run_evals
from phoenix.trace import SpanEvaluations, DocumentEvaluations

# %%
project_name = "lmz-rag-project"
px_client = Client()

nest_asyncio.apply()

# %%
df_retrieved_docs = get_retrieved_documents(
    px.Client(),
    project_name=project_name,
    timeout=None
)
df_retrieved_docs
# Out:
# Empty DataFrame
# Columns: [reference, input, context.trace_id, document_score]
# Index: []

# %%
df_qa = get_qa_with_reference(
    px.Client(),
    project_name=project_name,
    timeout=None
)
df_qa
# Out:
# No retrieval documents found.

# %%
raw = [
    {
        "question": "When does the course begin?",
        "answer_llm": "The course will begin on 15th Jan 2024 at 17h00.",
        "answer_orig": "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first “Office Hours'' live.\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
        "document": "c02e79ef",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.5477259159088135,
    },
    {
        "question": "How can I get the course schedule?",
        "answer_llm": "To get the course schedule, you can subscribe to the course public Google Calendar (it works from Desktop only). Additionally, you should register before the course starts using the provided link and join the course Telegram channel for announcements.",
        "answer_orig": "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first “Office Hours'' live.\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
        "document": "c02e79ef",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.5918357968330383,
    },
    {
        "question": "What is the link for course registration?",
        "answer_llm": "The link for course registration is not explicitly provided in the context. It is mentioned that you should \"register before the course starts using this link,\" but the actual link itself is not included.",
        "answer_orig": "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first “Office Hours'' live.\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
        "document": "c02e79ef",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.3959270417690277,
    },
    {
        "question": "How can I receive course announcements?",
        "answer_llm": "You can receive course announcements by joining the course Telegram channel and by registering in DataTalks.Club's Slack and joining the channel.",
        "answer_orig": "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first “Office Hours'' live.\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
        "document": "c02e79ef",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.7683022022247314,
    },
    {
        "question": "Where do I join the Slack channel?",
        "answer_llm": "You can join the Slack channel by registering in DataTalks.Club's Slack as mentioned in the course-related information.",
        "answer_orig": "The purpose of this document is to capture frequently asked technical questions\nThe exact day and hour of the course will be 15th Jan 2024 at 17h00. The course will start with the first “Office Hours'' live.\nSubscribe to course public Google Calendar (it works from Desktop only).\nRegister before the course starts using this link.\nJoin the course Telegram channel with announcements.\nDon’t forget to register in DataTalks.Club's Slack and join the channel.",
        "document": "c02e79ef",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.45097029209136963,
    },
    {
        "question": "Where can I find the prerequisites for this course?",
        "answer_llm": "You can find the prerequisites for this course on GitHub at the following link: DataTalksClub data-engineering-zoomcamp#prerequisites.",
        "answer_orig": "GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites",
        "document": "1f6520ca",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.8634203672409058,
    },
    {
        "question": "How do I check the prerequisites for this course?",
        "answer_llm": "To check the prerequisites for this course, you can visit the GitHub link provided: GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites.",
        "answer_orig": "GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites",
        "document": "1f6520ca",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.8626246452331543,
    },
    {
        "question": "Where are the course prerequisites listed?",
        "answer_llm": "The course prerequisites are listed at GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites.",
        "answer_orig": "GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites",
        "document": "1f6520ca",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.8158348798751831,
    },
    {
        "question": "What are the requirements for joining this course?",
        "answer_llm": "The requirements for joining this course include registering before the course starts using the provided link. Additionally, it is advised to join the course Telegram channel for announcements and to register in DataTalks.Club's Slack and join the relevant channel.",
        "answer_orig": "GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites",
        "document": "1f6520ca",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.481030136346817,
    },
    {
        "question": "Where is the list of prerequisites for the course?",
        "answer_llm": "The list of prerequisites for the course can be found at GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites.",
        "answer_orig": "GitHub - DataTalksClub data-engineering-zoomcamp#prerequisites",
        "document": "1f6520ca",
        "course": "data-engineering-zoomcamp",
        "cosine_similarity": 0.8535115718841553,
    },
]

df_eval = pd.DataFrame(
    {
        "input": [r["question"] for r in raw],
        "output": [r["answer_llm"] for r in raw],
        "reference": [r["answer_orig"] for r in raw],
        "document_id": [r["document"] for r in raw],
        "course": [r["course"] for r in raw],
        "retrieval_score": [r["cosine_similarity"] for r in raw],
    }
)

df_eval
# Out:
#                                                input  \
# 0                        When does the course begin?
# 1                 How can I get the course schedule?
# 2          What is the link for course registration?
# 3            How can I receive course announcements?
# 4                 Where do I join the Slack channel?
# 5  Where can I find the prerequisites for this co...
# 6  How do I check the prerequisites for this course?
# 7         Where are the course prerequisites listed?
# 8  What are the requirements for joining this cou...
# 9  Where is the list of prerequisites for the cou...
#
#                                               output  \
# 0   The course will begin on 15th Jan 2024 at 17h00.
# 1  To get the course schedule, you can subscribe ...
# 2  The link for course registration is not explic...
# 3  You can receive course announcements by joinin...
# 4  You can join the Slack channel by registering ...
# 5  You can find the prerequisites for this course...
# ...

# %%
eval_model = OpenAIModel(model="gpt-4o-mini")

relevance_evaluator = RelevanceEvaluator(eval_model)
hallucination_evaluator = HallucinationEvaluator(eval_model)
qa_evaluator = QAEvaluator(eval_model)

# %%
relevance_df, hallucination_df, qa_df = run_evals(
    evaluators=[relevance_evaluator, hallucination_evaluator, qa_evaluator],
    dataframe=df_eval.iloc[0:3],
    provide_explanation=True,
    concurrency=1
)
# Out:
# run_evals |          | 0/9 (0.0%) | ⏳ 00:00<? | ?it/s
# Rate limit throttle on attempt 1: raised RateLimitError('Rate limited: throttling requests to 5.335327715330789 RPS')
# Requeuing...
# Rate limit throttle on attempt 2: raised RateLimitError('Rate limited: throttling requests to 2.804546121593913 RPS')
# Requeuing...
# Rate limit throttle on attempt 1: raised RateLimitError('Rate limited: throttling requests to 1.5122238726830664 RPS')
# Requeuing...
# Rate limit throttle on attempt 2: raised RateLimitError('Rate limited: throttling requests to 0.7949071220065371 RPS')
# Requeuing...
# Rate limit throttle on attempt 3: raised RateLimitError('Rate limited: throttling requests to 0.41784847997774155 RPS')
# Requeuing...
# Rate limit throttle on attempt 4: raised RateLimitError('Rate limited: throttling requests to 0.21964372890140327 RPS')
# Requeuing...
# Rate limit throttle on attempt 5: raised RateLimitError('Rate limited: throttling requests to 0.11545650547901423 RPS')
# ...

# %%
pd.set_option('display.max_colwidth', None)

# %%
relevance_df
# Out:
#       label  score  \
# 0  relevant      1
# 1  relevant      1
# 2  relevant      1
#
#                                                                                                                                                                                                                                                                                                                                                                                                          explanation
# 0                                                                                                                                                                                           The reference text provides specific information about the start date and time of the course, stating that it will begin on 15th Jan 2024 at 17h00. This directly answers the question regarding when the course begins.
# ...

# %%
hallucination_df
# Out:
#      label  score  \
# 0  factual      0
# 1  factual      0
# 2  factual      0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        explanation
# ...

# %%
qa_df
# Out:
#        label  score  \
# 0    correct      1
# 1    correct      1
# 2  incorrect      0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 explanation
# ...
